# %% [markdown]
# # Module 4: PHON Tutorial - Phonemes
#
# ## Before the Tutorial Session
#
#
# Please read this paper on the use/misuse of the term phoneme:
#
# [https://www.isca-speech.org/archive/Interspeech_2019/pdfs/2711.pdf](https://www.isca-speech.org/archive/Interspeech_2019/pdfs/2711.pdf)
#
#
# Write down (with pen and paper or equivalent) answers to the following questions.
#
#
# 1) Fill the gaps:
#
#
#
# * 1) There is a `______________________________________` is often used in a  `_______________________`, based on a mistaken belief that it is a `_______________________`  block rather than an  `_______________________`                                                                .
#
#
#
# * 2) The sounds listeners perceive - the ‘phonemes’ - are conditioned `_______________________` , not on a fixed `____________________________________`.                                         .
#
#
#
# * 3) The convention is that a `_______________________` consists of IPA symbols between forward slashes, and a `_______________________`   consists of IPA symbols between square brackets
#
#
#
# * 4) Individual speech sounds may be ‘heard’ `_______________________`   `_______________________`  and second, whole words or phrases may be ‘heard’                                         !
#
#
#
# * 5) Speakers and listeners continuously balance the`____________________________________`  against the `_______________________________________`  [22] - behaviour that leads to a `_______________________`  (as opposed to signal-based) form of communication [23].
#
#
#
# * 6) What is particularly noticeable is that most of these frequently occurring bigram phrases are more related to `___________________________` than to speech science.
#
#
#
# * 7) What is perhaps most concerning is that `____________`  of the INTERSPEECH-2018 papers that used the term ‘phoneme’ did not provide any form of definition or explanation, presumably because the authors assumed that
#
#
#
# * 8) Further analysis of the `________`  accepted papers in INTERSPEECH2018 that contained the term ‘phoneme’ showed that around `____________` used the term in a way that could be construed as `_______________________`.
#
#
#
# * 9) Other authors clearly assumed that there is a fixed relationship between `_______________________`  and its`___________________________________` , and that boundaries between `____________________________________`  existed and were well defined.
#
#
#
# * 10) Many authors referred to `_______________________`  and the derivation of `________________________` . One even referred to `___________________________________` !
#
#
#
# * 11) It should be acknowledged that around `_______________`  of the 265 accepted papers in INTERSPEECH-2018 that contained the term ‘phoneme’ `_______________________` the term in an inappropriate manner
#
#
#
# * 12) It was noticeable that authors in the areas of `_______________________`  and `____________________________`  were considerably more `_______________________`  in their usage.
#
#
#
# * 13) In many cases, the term ‘phoneme’ could have been substituted by `_______________________`  with no loss of meaning.
#
#
#
# * 14) Many language resources are supplied with predefined so called `_______________________`  labels, often using their own `_______________________` symbol sets.
#
#
#
# * 15) Using forced-alignment with such labels reinforces the superficial`_______________________`  view of speech
#
#
#
# * 16) Using the term ‘phoneme’ correctly is certainly a small price to pay to avoid such outcomes, and may even lead to `_________________________________`  into the structure and behaviour of spoken language - especially when coupled with contemporary ideas in deep learning [28], such as `__________________________` [29] and  `_______________________________` [30].
#
#
# 2) What is Daniel Jones’ definition of a phoneme?
#
#
#
# 3) What is the phoneme restoration effect?
#
#
#
# 4) Describe the effect illustrated by Sara Hawkins.
#
#
# 5) What % of papers contained the term “phoneme”, “speech recognition” and “speech synthesis” at Interspeech 2018 and ICSLP-1998?
#
#
# 6) What do the authors note is particularly noticeable about Table 3?
#
#
# 7) Of the definitions for the term “phoneme” given at Interspeech 2018, how many were correct?
#
#
# 8) How many papers correctly defined the term “phoneme” at Interspeech 2018?
#
#
#
# 9) In section 3.3 the authors give a list of examples of the misuse of the term “phoneme” The author gives a short explanation for each that is not comprehensive. Choose 3 examples and explain fully why each is a misuse.
#
#
# 10) Do speech technology papers misuse the term as much as speech science papers?
#
#
#
# 11) What are the 3 recommendations made by the authors in section 4.2?
#
#
#
# 12) Do you now personally understand the meaning of the term phoneme? Bring your questions to the tutorial.
#
#
#
# _BONUS QUESTION:_ What is a metaphoneme?
